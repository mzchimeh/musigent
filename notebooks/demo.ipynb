# %% [markdown]
# # Musigent Demo Notebook
# Demo of MusigentRunner

# %%
from musigent.runner import MusigentRunner
runner = MusigentRunner()
runner.handle_request('jingle', 'modern tech-startup jingle', 15)
